# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH
import subprocess
from docx.shared import Pt
import pandas as pd
import numpy as np
import os
import shutil
from tqdm import tqdm
import glob
from zipfile import ZipFile 
import concurrent
pd.options.mode.chained_assignment = None 
import json
from docx.shared import RGBColor

# %%
df = pd.read_excel('data_sample_generated.xlsx')

# %%
df['price_qty'] = df['price_qty'].round(0)
df['vat']= df['price_qty'].round(0)
df['amount']= df['price_qty'].round(0)
df
# Out:
#                      company_name         invoice_date    invoice_no  \
# 0   PT SUITMEDIA KREASI INDONESIA  2026-04-06 00:00:00  INVGDTI50460
# 1   PT SUITMEDIA KREASI INDONESIA  2026-04-06 00:00:00  INVGDTI50460
# 2   PT SUITMEDIA KREASI INDONESIA  2026-04-06 00:00:00  INVGDTI50460
# 3                          PT 123  2026-04-07 00:00:00  INVGDTI50461
# 4                          PT 123  2026-04-07 00:00:00  INVGDTI50461
# ..                            ...                  ...           ...
# 69                         PT 123           2026-04-18  INVGDTI50490
# 70                         PT 123           2026-04-18  INVGDTI50490
# 71                         PT 123           2026-04-18  INVGDTI50490
# 72                         PT 123           2026-05-19  INVGDTI50491
# 73                         PT 123           2026-05-19  INVGDTI50491
#
#                        description  qty  price_qty     amount        vat  po  \
# 0                  Consultation GP   15    27000.0    27000.0    27000.0 NaN
# 1                  Consultation SP    8   100000.0   100000.0   100000.0 NaN
# 2   Reimbursement of drug purchase    1  5799435.0  5799435.0  5799435.0 NaN
# 3                  Consultation GP   15    27000.0    27000.0    27000.0 NaN
# 4                  Consultation SP    8   100000.0   100000.0   100000.0 NaN
# ..                             ...  ...        ...        ...        ...  ..
# 69         Specialist Referral Fee   14    75000.0    75000.0    75000.0 NaN
# 70            Telemedicine Session   15    50000.0    50000.0    50000.0 NaN
# 71              Home Visit Service    2   500000.0   500000.0   500000.0 NaN
# 72            Telemedicine Session    8    50000.0    50000.0    50000.0 NaN
# 73                 Consultation SP    7   100000.0   100000.0   100000.0 NaN
#
#                        address_1  ...  \
# 0   Gedung Plaza City View Lt. 2  ...
# 1   Gedung Plaza City View Lt. 3  ...
# 2   Gedung Plaza City View Lt. 4  ...
# 3   Gedung Plaza City View Lt. 2  ...
# 4   Gedung Plaza City View Lt. 3  ...
# ..                           ...  ...
# 69  Gedung Plaza City View Lt. 2  ...
# 70  Gedung Plaza City View Lt. 2  ...
# 71  Gedung Plaza City View Lt. 2  ...
# 72  Gedung Plaza City View Lt. 2  ...
# 73  Gedung Plaza City View Lt. 2  ...
#
#                                           address_3        address_4  \
# 0   Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 1   Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 2   Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 3   Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 4   Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# ..                                              ...              ...
# 69  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 70  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 71  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 72  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 73  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
#
#           address_5               payment_notes payment_notes_2  \
# 0   Indonesia 12510  1. Term of Payment 30 days             NaN
# 1   Indonesia 12511  1. Term of Payment 30 days             NaN
# 2   Indonesia 12512  1. Term of Payment 30 days             NaN
# 3   Indonesia 12510  1. Term of Payment 30 days             NaN
# 4   Indonesia 12511  1. Term of Payment 30 days             NaN
# ..              ...                         ...             ...
# 69  Indonesia 12510  1. Term of Payment 30 days             NaN
# 70  Indonesia 12510  1. Term of Payment 30 days             NaN
# 71  Indonesia 12510  1. Term of Payment 30 days             NaN
# 72  Indonesia 12510  1. Term of Payment 30 days             NaN
# 73  Indonesia 12510  1. Term of Payment 30 days             NaN
#
#                       bank_account_name            bank bank_account_number  \
# 0   PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 1   PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 2   PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 3   PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 4   PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# ..                                  ...             ...                 ...
# 69  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 70  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 71  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 72  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 73  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
#
#                       bank_branch swift_code
# 0   Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 1   Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 2   Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 3   Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 4   Bank OCBC NISP Cab Rawamangun   NISPIDJA
# ..                            ...        ...
# 69  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 70  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 71  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 72  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 73  Bank OCBC NISP Cab Rawamangun   NISPIDJA
#
# [74 rows x 21 columns]

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date']).dt.strftime('%d/%m/%Y')



data = df[df['invoice_no'] == 'INVGDTI50460'].fillna('').to_dict(orient = 'records')
data
# Out:
# [{'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': '06/04/2026',
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Consultation GP',
#   'qty': 15,
#   'price_qty': 27000.0,
#   'amount': 27000.0,
#   'vat': 27000.0,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 2',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 008',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12510',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_branch': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'},
#  {'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': '06/04/2026',
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Consultation SP',
#   'qty': 8,
#   'price_qty': 100000.0,
#   'amount': 100000.0,
#   'vat': 100000.0,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 3',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 009',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12511',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_branch': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'},
#  {'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': '06/04/2026',
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Reimbursement of drug purchase',
#   'qty': 1,
#   'price_qty': 5799435.0,
#   'amount': 5799435.0,
#   'vat': 5799435.0,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 4',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 010',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12512',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_branch': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'}]

# %%
from docx.shared import Pt
from docx.oxml.ns import qn
from docx.oxml import OxmlElement
from docx.enum.text import WD_ALIGN_PARAGRAPH
from tqdm import tqdm

def set_cell_text(cell, text, font_size=9, font_name='Arial', font_color=None, bold=False, align=None):
    """Set cell text with font formatting."""
    cell.text = (text or '').strip()
    for paragraph in cell.paragraphs:
        pPr = paragraph._p.get_or_add_pPr()
        spacing = OxmlElement('w:spacing')
        spacing.set(qn('w:after'), '0')
        spacing.set(qn('w:before'), '0')
        pPr.append(spacing)

        if align:
            paragraph.alignment = align  # 👈

        for run in paragraph.runs:
            run.font.size = Pt(font_size)
            run.font.name = font_name
            run.font.bold = bold
            if font_color:
                run.font.color.rgb = font_color
                
for i in tqdm(df.invoice_no.unique(), total = df.invoice_no.nunique()):
    data = df[df['invoice_no'] == i].fillna('').to_dict(orient = 'records')
    f = open('Finance Invoice template.docx', 'rb')
    
    
                    
    doc = Document(f)
    
    # Dynamic rows — line items
    subtotal = sum([x.get('amount', 0) for x in data])
    vat = sum([x.get('vat', 0) for x in data])
    total = f"Rp. {(round(subtotal + vat)):,}".replace('.0', '')
    
    subtotal = f"Rp. {round(subtotal):,}".replace('.0', '')
    vat =f"Rp. {round(vat):,}".replace('.0', '')
    
        
    inv_no = data[0].get('invoice_no')
    # Static fields
    static_cells = [
        (1, 4, data[0].get('invoice_date')),
        (2, 4, inv_no),
        (3, 4, data[0].get('po')),
        (14, 0, data[0].get('company_name')),
        (15, 0, data[0].get('address_1')),
        (16, 0, data[0].get('address_2')),
        (17, 0, data[0].get('address_3')),
        (18, 0, data[0].get('address_4')),
        (19, 0, data[0].get('address_5')),
        # (27, 4, str(subtotal).replace('.0', '')),
        # (28, 4, str(vat).replace('.0', '')),
        # (29, 4, str(total).replace('.0', '')),  # fixed: was overwriting row 28 twice
        (32, 0, data[0].get('payment_notes')),
        (36, 0, 'Account Name           : ' + str(data[0].get('bank_account_name', '')).replace('.0', '')),
        (37, 0, 'Bank                          : ' + str(data[0].get('bank', ''))),
        (38, 0, 'Account Number        : ' + str(data[0].get('bank_account_number', ''))),
        (39, 0, 'Branch                       : ' + str(data[0].get('bank_branch', ''))),
        (40, 0, 'Swift Code                 : ' + str(data[0].get('swift_code', ''))),  # fixed: was overwriting row 39
    ]
    
    for row, col, value in static_cells:
        set_cell_text(doc.tables[0].cell(row, col), value)
    
    # Bold cells — subtotal, vat, total
    set_cell_text(doc.tables[0].cell(27, 4), str(subtotal).replace('.0', ''), bold=True)
    set_cell_text(doc.tables[0].cell(28, 4), str(vat).replace('.0', ''),      bold=True)
    set_cell_text(doc.tables[0].cell(29, 4), str(total).replace('.0', ''),    bold=True)
    
    set_cell_text(doc.tables[0].cell(27, 3), "Subtotal", bold=True, align=WD_ALIGN_PARAGRAPH.RIGHT)
    set_cell_text(doc.tables[0].cell(28, 3), "VAT Total",      bold=True, align=WD_ALIGN_PARAGRAPH.RIGHT)
    set_cell_text(doc.tables[0].cell(29, 3), "Total",    bold=True, align=WD_ALIGN_PARAGRAPH.RIGHT)
    
    for i, item in enumerate(data):
        set_cell_text(doc.tables[0].cell(22 + i, 0), item.get('description'))
        set_cell_text(doc.tables[0].cell(22 + i, 2), f"{item.get('price_qty', ''):,}".replace('.0', ''), align=WD_ALIGN_PARAGRAPH.RIGHT)
        set_cell_text(doc.tables[0].cell(22 + i, 3), str(item.get('qty', '')).replace('.0', ''), align=WD_ALIGN_PARAGRAPH.RIGHT)
        set_cell_text(doc.tables[0].cell(22 + i, 4), f"{float(item.get('amount', '')):,}".replace('.0', ''), align=WD_ALIGN_PARAGRAPH.RIGHT)
    
    
    if not os.path.exists(f'output'):
        os.makedirs(f'output')
    
    tmp_name = f'output/Invoice_{inv_no}.docx'
    doc.save(tmp_name)
    f.close()
    subprocess.run(['libreoffice', '--convert-to', 'pdf' ,
                        tmp_name, '--outdir', 'output']
                       ,stdout=subprocess.DEVNULL,
                        stderr=subprocess.DEVNULL
                    )
        
    os.remove(tmp_name)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [01:55<00:00,  3.61s/it]

# %%
data
# Out:
#                     company_name invoice_date    invoice_no  \
# 0  PT SUITMEDIA KREASI INDONESIA   04/06/2026  INVGDTI50460
# 1  PT SUITMEDIA KREASI INDONESIA   04/06/2026  INVGDTI50460
# 2  PT SUITMEDIA KREASI INDONESIA   04/06/2026  INVGDTI50460
#
#                       description  qty  price_qty     amount        vat  po  \
# 0                 Consultation GP   15    27000.0    27000.0    27000.0 NaN
# 1                 Consultation SP    8   100000.0   100000.0   100000.0 NaN
# 2  Reimbursement of drug purchase    1  5799435.0  5799435.0  5799435.0 NaN
#
#                       address_1  ...  \
# 0  Gedung Plaza City View Lt. 2  ...
# 1  Gedung Plaza City View Lt. 3  ...
# 2  Gedung Plaza City View Lt. 4  ...
#
#                                          address_3        address_4  \
# 0  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 1  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
# 2  Kelurahan Pejaten Barat, Kecamatan Pasar Minggu  Jakarta Selatan
#
#          address_5               payment_notes payment_notes_2  \
# 0  Indonesia 12510  1. Term of Payment 30 days             NaN
# 1  Indonesia 12511  1. Term of Payment 30 days             NaN
# 2  Indonesia 12512  1. Term of Payment 30 days             NaN
#
#                      bank_account_name            bank bank_account_number  \
# 0  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 1  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
# 2  PT Good Doctor Technology Indonesia  BANK OCBC NISP        577800006618
#
#                      bank_brancj swift_code
# 0  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 1  Bank OCBC NISP Cab Rawamangun   NISPIDJA
# 2  Bank OCBC NISP Cab Rawamangun   NISPIDJA
#
# [3 rows x 21 columns]

# %%
subtotal = sum([x.get('amount', 0) for x in data])
vat = sum([x.get('vat', 0) for x in data])
total = f"{(round(subtotal + vat)):,}".replace('.0', '')

# %%
total
# Out:
# '11,852,870'

# %%
doc = Document(f)

# %%
#date
doc.tables[0].cell(1, 4).text = data[0].get('invoice_date')

# invoice
doc.tables[0].cell(2, 4).text = data[0].get('invoice_no')

#PO
doc.tables[0].cell(3, 4).text = data[0].get('po')

#company
doc.tables[0].cell(14, 0).text = data[0].get('company_name')

#address 1
doc.tables[0].cell(15, 0).text = data[0].get('address_1')

#address 2
doc.tables[0].cell(16, 0).text = data[0].get('address_2')

#address 3
doc.tables[0].cell(17, 0).text = data[0].get('address_3')

#address 4
doc.tables[0].cell(18, 0).text = data[0].get('address_4')

#address 5
doc.tables[0].cell(19, 0).text = data[0].get('address_5')

for i in range(data):
    doc.tables[0].cell(23+i, 0).text = i['description']
    doc.tables[1].cell(23+i, 1).text = i['price_qty']
    doc.tables[1].cell(23+i, 2).text = i['qty']
    doc.tables[1].cell(23+i, 3).text = i['amount']

subtotal = sum([x.get('amount',0) for x in data])
vat = sum([x.get('vat',0) for x in data])
total = subtotal + vat

doc.tables[0].cell(27, 4).text = subtotal
doc.tables[0].cell(28, 4).text = vat
doc.tables[0].cell(28, 4).text = total
doc.tables[0].cell(32, 0).text = data[0].get('payment_notes')
doc.tables[0].cell(36, 0).text = 'Account Name           : ' + data[0].get('bank_account_name').astype(str).replace('.0', '')
doc.tables[0].cell(37, 0).text = 'Bank                          : ' + data[0].get('bank').astype(str).replace('.0', '')
doc.tables[0].cell(38, 0).text = 'Account Number        : ' + data[0].get('bank_account_number').astype(str).replace('.0', '')
doc.tables[0].cell(39, 0).text = 'Branch                       : ' + data[0].get('bank_branch').astype(str).replace('.0', '')
doc.tables[0].cell(39, 0).text = 'Swift Code                 : ' + data[0].get('swift_code').astype(str).replace('.0', '')
# Out:
# 'Indonesia 12510'

# %%
for i in range(data):
    doc.tables[0].cell(23+i, 0).text = i['description']
    doc.tables[1].cell(23+i, 1).text = i['price_qty']
    doc.tables[1].cell(23+i, 2).text = i['qty']
    doc.tables[1].cell(23+i, 3).text = i['amount']
# Out:
# 'Consultation SP'

# %%
doc.tables[0].cell(36, 0).text
# Out:
# 'Account Name           : PT Good Doctor Technology Indonesia'

# %%
for i in range(20):
    for j in range(20):
        print(i,j, '==>', doc.tables[0].cell(i, j).text)
# Out:
# 0 0 ==>
#
# 0 1 ==>
# 0 2 ==>
# 0 3 ==> Invoice
# 0 4 ==>
# 0 5 ==>
# 0 6 ==>
# 0 7 ==>
# 0 8 ==> Date
# 0 9 ==> 06/04/2026
# 0 10 ==>
# 0 11 ==>
# 0 12 ==>
# 0 13 ==> Invoice #
# 0 14 ==> INVGDTI50460
# 0 15 ==>
# 0 16 ==>
# 0 17 ==>
# 0 18 ==>
# 0 19 ==>
# 1 0 ==>
# 1 1 ==>
# 1 2 ==>
# 1 3 ==> Date
# 1 4 ==> 06/04/2026
# 1 5 ==>
# 1 6 ==>
# 1 7 ==>
# 1 8 ==> Invoice #
# 1 9 ==> INVGDTI50460
# 1 10 ==>
# 1 11 ==>
# 1 12 ==>
# 1 13 ==>
# 1 14 ==>
# 1 15 ==> PT Good Doctor Technology Indonesia
# 1 16 ==>
# 1 17 ==>
# 1 18 ==> PO #
# 1 19 ==>
# 2 0 ==>
# 2 1 ==>
# 2 2 ==>
# 2 3 ==> Invoice #
# 2 4 ==> INVGDTI50460
# 2 5 ==>
# 2 6 ==>
# 2 7 ==>
# 2 8 ==>
# 2 9 ==>
# 2 10 ==> PT Good Doctor Technology Indonesia
# 2 11 ==>
# 2 12 ==>
# 2 13 ==> PO #
# 2 14 ==>
# 2 15 ==> Gedung Capital Place Lt. 42
# 2 16 ==>
# 2 17 ==>
# 2 18 ==>
# 2 19 ==>
# 3 0 ==>
# 3 1 ==>
# 3 2 ==>
# 3 3 ==>
# 3 4 ==>
# 3 5 ==> PT Good Doctor Technology Indonesia
# 3 6 ==>
# 3 7 ==>
# 3 8 ==> PO #
# 3 9 ==>
# 3 10 ==> Gedung Capital Place Lt. 42
# 3 11 ==>
# 3 12 ==>
# 3 13 ==>
# 3 14 ==>
# 3 15 ==> JL. Jend. Gatot Subroto Kav. 18
# 3 16 ==>
# 3 17 ==>
# 3 18 ==>
# 3 19 ==>
# 4 0 ==> PT Good Doctor Technology Indonesia
# 4 1 ==>
# 4 2 ==>
# 4 3 ==> PO #
# 4 4 ==>
# 4 5 ==> Gedung Capital Place Lt. 42
# 4 6 ==>
# 4 7 ==>
# 4 8 ==>
# 4 9 ==>
# 4 10 ==> JL. Jend. Gatot Subroto Kav. 18
# 4 11 ==>
# 4 12 ==>
# 4 13 ==>
# 4 14 ==>
# 4 15 ==> Kuningan Barat, Mampang Prapatan
# 4 16 ==>
# 4 17 ==>
# 4 18 ==>
# 4 19 ==>
# 5 0 ==> Gedung Capital Place Lt. 42
# 5 1 ==>
# 5 2 ==>
# 5 3 ==>
# 5 4 ==>
# 5 5 ==> JL. Jend. Gatot Subroto Kav. 18
# 5 6 ==>
# 5 7 ==>
# 5 8 ==>
# 5 9 ==>
# 5 10 ==> Kuningan Barat, Mampang Prapatan
# 5 11 ==>
# 5 12 ==>
# 5 13 ==>
# 5 14 ==>
# 5 15 ==> Jakarta Selatan
# 5 16 ==>
# 5 17 ==>
# 5 18 ==>
# 5 19 ==>
# 6 0 ==> JL. Jend. Gatot Subroto Kav. 18
# 6 1 ==>
# 6 2 ==>
# 6 3 ==>
# 6 4 ==>
# 6 5 ==> Kuningan Barat, Mampang Prapatan
# 6 6 ==>
# 6 7 ==>
# 6 8 ==>
# 6 9 ==>
# 6 10 ==> Jakarta Selatan
# 6 11 ==>
# 6 12 ==>
# 6 13 ==>
# 6 14 ==>
# 6 15 ==> Indonesia 12710
# 6 16 ==>
# 6 17 ==>
# 6 18 ==>
# 6 19 ==>
# 7 0 ==> Kuningan Barat, Mampang Prapatan
# 7 1 ==>
# 7 2 ==>
# 7 3 ==>
# 7 4 ==>
# 7 5 ==> Jakarta Selatan
# 7 6 ==>
# 7 7 ==>
# 7 8 ==>
# 7 9 ==>
# 7 10 ==> Indonesia 12710
# 7 11 ==>
# 7 12 ==>
# 7 13 ==>
# 7 14 ==>
# 7 15 ==> Tax ID # 91.654.365.5-063.000
# 7 16 ==>
# 7 17 ==>
# 7 18 ==>
# 7 19 ==>
# 8 0 ==> Jakarta Selatan
# 8 1 ==>
# 8 2 ==>
# 8 3 ==>
# 8 4 ==>
# 8 5 ==> Indonesia 12710
# 8 6 ==>
# 8 7 ==>
# 8 8 ==>
# 8 9 ==>
# 8 10 ==> Tax ID # 91.654.365.5-063.000
# 8 11 ==>
# 8 12 ==>
# 8 13 ==>
# 8 14 ==>
# 8 15 ==>
# 8 16 ==>
# 8 17 ==>
# 8 18 ==>
# 8 19 ==>
# 9 0 ==> Indonesia 12710
# 9 1 ==>
# 9 2 ==>
# 9 3 ==>
# 9 4 ==>
# 9 5 ==> Tax ID # 91.654.365.5-063.000
# 9 6 ==>
# 9 7 ==>
# 9 8 ==>
# 9 9 ==>
# 9 10 ==>
# 9 11 ==>
# 9 12 ==>
# 9 13 ==>
# 9 14 ==>
# 9 15 ==>
# 9 16 ==>
# 9 17 ==>
# 9 18 ==>
# 9 19 ==>
# 10 0 ==> Tax ID # 91.654.365.5-063.000
# 10 1 ==>
# 10 2 ==>
# 10 3 ==>
# 10 4 ==>
# 10 5 ==>
# 10 6 ==>
# 10 7 ==>
# 10 8 ==>
# 10 9 ==>
# 10 10 ==>
# 10 11 ==>
# 10 12 ==>
# 10 13 ==>
# 10 14 ==>
# 10 15 ==> Bill to
# 10 16 ==>
# 10 17 ==>
# 10 18 ==>
# 10 19 ==>
# 11 0 ==>
# 11 1 ==>
# 11 2 ==>
# 11 3 ==>
# 11 4 ==>
# 11 5 ==>
# 11 6 ==>
# 11 7 ==>
# 11 8 ==>
# 11 9 ==>
# 11 10 ==> Bill to
# 11 11 ==>
# 11 12 ==>
# 11 13 ==>
# 11 14 ==>
# 11 15 ==> PT SUITMEDIA KREASI INDONESIA
# 11 16 ==>
# 11 17 ==>
# 11 18 ==>
# 11 19 ==>
# 12 0 ==>
# 12 1 ==>
# 12 2 ==>
# 12 3 ==>
# 12 4 ==>
# 12 5 ==> Bill to
# 12 6 ==>
# 12 7 ==>
# 12 8 ==>
# 12 9 ==>
# 12 10 ==> PT SUITMEDIA KREASI INDONESIA
# 12 11 ==>
# 12 12 ==>
# 12 13 ==>
# 12 14 ==>
# 12 15 ==> Gedung Plaza City View Lt. 2
# 12 16 ==>
# 12 17 ==>
# 12 18 ==>
# 12 19 ==>
# 13 0 ==> Bill to
# 13 1 ==>
# 13 2 ==>
# 13 3 ==>
# 13 4 ==>
# 13 5 ==> PT SUITMEDIA KREASI INDONESIA
# 13 6 ==>
# 13 7 ==>
# 13 8 ==>
# 13 9 ==>
# 13 10 ==> Gedung Plaza City View Lt. 2
# 13 11 ==>
# 13 12 ==>
# 13 13 ==>
# 13 14 ==>
# 13 15 ==> Jl. Kemang Timur No. 22, RT. 001/RW. 008
# 13 16 ==>
# 13 17 ==>
# 13 18 ==>
# 13 19 ==>
# 14 0 ==> PT SUITMEDIA KREASI INDONESIA
# 14 1 ==>
# 14 2 ==>
# 14 3 ==>
# 14 4 ==>
# 14 5 ==> Gedung Plaza City View Lt. 2
# 14 6 ==>
# 14 7 ==>
# 14 8 ==>
# 14 9 ==>
# 14 10 ==> Jl. Kemang Timur No. 22, RT. 001/RW. 008
# 14 11 ==>
# 14 12 ==>
# 14 13 ==>
# 14 14 ==>
# 14 15 ==> Kelurahan Pejaten Barat, Kecamatan Pasar Minggu
# 14 16 ==>
# 14 17 ==>
# 14 18 ==>
# 14 19 ==>
# 15 0 ==> Gedung Plaza City View Lt. 2
# 15 1 ==>
# 15 2 ==>
# 15 3 ==>
# 15 4 ==>
# 15 5 ==> Jl. Kemang Timur No. 22, RT. 001/RW. 008
# 15 6 ==>
# 15 7 ==>
# 15 8 ==>
# 15 9 ==>
# 15 10 ==> Kelurahan Pejaten Barat, Kecamatan Pasar Minggu
# 15 11 ==>
# 15 12 ==>
# 15 13 ==>
# 15 14 ==>
# 15 15 ==> Jakarta Selatan
# 15 16 ==>
# 15 17 ==>
# 15 18 ==>
# 15 19 ==>
# 16 0 ==> Jl. Kemang Timur No. 22, RT. 001/RW. 008
# 16 1 ==>
# 16 2 ==>
# 16 3 ==>
# 16 4 ==>
# 16 5 ==> Kelurahan Pejaten Barat, Kecamatan Pasar Minggu
# 16 6 ==>
# 16 7 ==>
# 16 8 ==>
# 16 9 ==>
# 16 10 ==> Jakarta Selatan
# 16 11 ==>
# 16 12 ==>
# 16 13 ==>
# 16 14 ==>
# 16 15 ==> Indonesia 12510
# 16 16 ==>
# 16 17 ==>
# 16 18 ==>
# 16 19 ==>
# 17 0 ==> Kelurahan Pejaten Barat, Kecamatan Pasar Minggu
# 17 1 ==>
# 17 2 ==>
# 17 3 ==>
# 17 4 ==>
# 17 5 ==> Jakarta Selatan
# 17 6 ==>
# 17 7 ==>
# 17 8 ==>
# 17 9 ==>
# 17 10 ==> Indonesia 12510
# 17 11 ==>
# 17 12 ==>
# 17 13 ==>
# 17 14 ==>
# 17 15 ==>
# 17 16 ==>
# 17 17 ==>
# 17 18 ==>
# 17 19 ==>
# 18 0 ==> Jakarta Selatan
# 18 1 ==>
# 18 2 ==>
# 18 3 ==>
# 18 4 ==>
# 18 5 ==> Indonesia 12510
# 18 6 ==>
# 18 7 ==>
# 18 8 ==>
# 18 9 ==>
# 18 10 ==>
# 18 11 ==>
# 18 12 ==>
# 18 13 ==>
# 18 14 ==>
# 18 15 ==> Item
# 18 16 ==> Item
# 18 17 ==>  Price
# 18 18 ==> Qty
# 18 19 ==> Total
# 19 0 ==> Indonesia 12510
# 19 1 ==>
# 19 2 ==>
# 19 3 ==>
# 19 4 ==>
# 19 5 ==>
# 19 6 ==>
# 19 7 ==>
# 19 8 ==>
# 19 9 ==>
# 19 10 ==> Item
# 19 11 ==> Item
# 19 12 ==>  Price
# 19 13 ==> Qty
# 19 14 ==> Total
# 19 15 ==> Consultation GP
# 19 16 ==>
# 19 17 ==>                 27,000
# 19 18 ==>                15
# 19 19 ==>                                     405,000

# %%
data
# Out:
# [{'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': Timestamp('2026-04-06 00:00:00'),
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Consultation GP',
#   'qty': 15,
#   'price_qty': 26999.999999999996,
#   'amount': 404999.99999999994,
#   'vat': 44549.99999999999,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 2',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 008',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12510',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_brancj': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'},
#  {'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': Timestamp('2026-04-06 00:00:00'),
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Consultation SP',
#   'qty': 8,
#   'price_qty': 99999.99999999999,
#   'amount': 799999.9999999999,
#   'vat': 87999.99999999997,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 3',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 009',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12511',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_brancj': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'},
#  {'company_name': 'PT SUITMEDIA KREASI INDONESIA',
#   'invoice_date': Timestamp('2026-04-06 00:00:00'),
#   'invoice_no': 'INVGDTI50460',
#   'description': 'Reimbursement of drug purchase',
#   'qty': 1,
#   'price_qty': 5799435.0,
#   'amount': 5799435.0,
#   'vat': 0.0,
#   'po': '',
#   'address_1': 'Gedung Plaza City View Lt. 4',
#   'address_2': 'Jl. Kemang Timur No. 22, RT. 001/RW. 010',
#   'address_3': 'Kelurahan Pejaten Barat, Kecamatan Pasar Minggu',
#   'address_4': 'Jakarta Selatan',
#   'address_5': 'Indonesia 12512',
#   'payment_notes': '1. Term of Payment 30 days',
#   'payment_notes_2': '',
#   'bank_account_name': 'PT Good Doctor Technology Indonesia',
#   'bank': 'BANK OCBC NISP',
#   'bank_account_number': 577800006618,
#   'bank_brancj': 'Bank OCBC NISP Cab Rawamangun',
#   'swift_code': 'NISPIDJA'}]
